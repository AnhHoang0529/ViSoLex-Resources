# %%
# !pip install -qU tqdm

# %%
# !python /content/drive/MyDrive/LexNorm/KLTN/Code/Learning_From_Rule/generate_data.py
# Out:
# /content/drive/MyDrive/LexNorm/KLTN/Code/Learning_From_Rule/generate_data.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d_U['original'] = d_U['original'].apply(custom_str)
# /content/drive/MyDrive/LexNorm/KLTN/Code/Learning_From_Rule/generate_data.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d_U['regrex_rule'] = ''*len(d_U)
# /content/drive/MyDrive/LexNorm/KLTN/Code/Learning_From_Rule/generate_data.py:46: SettingWithCopyWarning:
# ...

# %%
import pandas as pd
from ast import literal_eval

train = pd.read_csv("/content/drive/MyDrive/LexNorm/KLTN/Code/astra/data/train.csv", converters={'input': literal_eval, 'output': literal_eval, 'regrex_rule': literal_eval, 'dict_rule': literal_eval})
test = pd.read_csv("/content/drive/MyDrive/LexNorm/KLTN/Code/astra/data/test.csv", converters={'input': literal_eval, 'output': literal_eval, 'regrex_rule': literal_eval, 'dict_rule': literal_eval})
dev = pd.read_csv("/content/drive/MyDrive/LexNorm/KLTN/Code/astra/data/dev.csv", converters={'input': literal_eval, 'output': literal_eval, 'regrex_rule': literal_eval, 'dict_rule': literal_eval})
d_U = pd.read_csv("/content/drive/MyDrive/LexNorm/KLTN/Code/astra/data/unlabeled.csv",  converters={'input': literal_eval, 'regrex_rule': literal_eval, 'dict_rule': literal_eval})

# %%
d_U[:50]
# Out:
#     Unnamed: 0                                           original  \
# 0            0  Em được làm fan cứng luôn rồi nè ❤ ️ reaction ...
# 1            1  Đúng là bọn mắt híp lò xo thụt :))) bên việt n...
# 2            2               @username giờ giống thằng sida hơn à
# 3            3  CÔN ĐỒ CỤC SÚC VÔ NHÂN TÍNH ĐỀ NGHI VN . NHÀ N...
# 4            4  Từ lý thuyết đến thực hành là cả 1 câu chuyện ...
# 5            5                             Coronavirus is manmade
# 6            6                              Đố chúng m nhận ra ai
# 7            7                                  Lúp lúp như chó .
# 8            8                                              🥰 🥰 🥰
# 9            9  Thế mà mình nói mấy thằng bắc kì , bọn đó lại ...
# 10          10     Được anh ưi , lâu rồi không nghe phúc du rap 🤣
# 11          11                 Cắt cho trẻ trâu bớt thui mà 😂 😂 😂
# 12          12            Nghe rất vô lí nhưng cực kì thuyết phục
# ...
